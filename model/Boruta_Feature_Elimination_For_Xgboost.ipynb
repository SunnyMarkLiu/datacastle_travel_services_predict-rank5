# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
color = sns.color_palette()
# %matplotlib inline
matplotlib.style.use('ggplot')

import time
import numpy as np
import pandas as pd
from IPython.display import display

# remove warnings
import warnings
warnings.filterwarnings('ignore')

import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import auc, roc_curve
from itertools import product

from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy

# my module
from conf.configure import Configure
from utils import data_utils, dataframe_util
from utils.common_utils import common_num_range

import model.get_datasets as gd

# %%
train, test = gd.load_datasets()

y_train = train['orderType']
train.drop(['orderType'], axis=1, inplace=True)

df_columns = train.columns.values
print('train: {}, test: {}, feature count: {}, orderType 1:0 = {:.5f}'.format(
    train.shape[0], test.shape[0], len(df_columns), 1.0*sum(y_train) / len(y_train)))
# Out:
# load baseline features
# merge advance_action_features1
# merge action_order_features2
# merge action_order_features1
# merge other_features1
# merge advance_order_history_features
# train: 40307, test: 10076, feature count: 552, orderType 1:0 = 0.16436

# %%
rfc = RandomForestClassifier(n_estimators=200, n_jobs=-1, class_weight='balanced', max_depth=6)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2)
boruta_selector.fit(train.fillna(-1).values, y_train.values)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	552
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	334
# Tentative: 	137
# Rejected: 	81
# Iteration: 	9 / 100
# Confirmed: 	334
# Tentative: 	137
# Rejected: 	81
# Iteration: 	10 / 100
# Confirmed: 	334
# Tentative: 	137
# Rejected: 	81
# Iteration: 	11 / 100
# Confirmed: 	334
# Tentative: 	137
# Rejected: 	81
# Iteration: 	12 / 100
# Confirmed: 	347
# Tentative: 	124
# Rejected: 	81
# Iteration: 	13 / 100
# Confirmed: 	347
# Tentative: 	124
# Rejected: 	81
# Iteration: 	14 / 100
# Confirmed: 	347
# Tentative: 	113
# Rejected: 	92
# Iteration: 	15 / 100
# Confirmed: 	347
# Tentative: 	113
# Rejected: 	92
# Iteration: 	16 / 100
# Confirmed: 	352
# Tentative: 	108
# Rejected: 	92
# Iteration: 	17 / 100
# Confirmed: 	352
# Tentative: 	108
# Rejected: 	92
# Iteration: 	18 / 100
# Confirmed: 	352
# Tentative: 	108
# Rejected: 	92
# Iteration: 	19 / 100
# Confirmed: 	353
# Tentative: 	107
# Rejected: 	92
# Iteration: 	20 / 100
# Confirmed: 	353
# Tentative: 	105
# Rejected: 	94
# Iteration: 	21 / 100
# Confirmed: 	353
# Tentative: 	105
# Rejected: 	94
# Iteration: 	22 / 100
# Confirmed: 	358
# Tentative: 	96
# Rejected: 	98
# Iteration: 	23 / 100
# Confirmed: 	358
# Tentative: 	96
# Rejected: 	98
# Iteration: 	24 / 100
# Confirmed: 	358
# Tentative: 	96
# Rejected: 	98
# Iteration: 	25 / 100
# Confirmed: 	358
# Tentative: 	96
# Rejected: 	98
# Iteration: 	26 / 100
# Confirmed: 	359
# Tentative: 	92
# Rejected: 	101
# Iteration: 	27 / 100
# Confirmed: 	359
# Tentative: 	92
# Rejected: 	101
# Iteration: 	28 / 100
# Confirmed: 	359
# Tentative: 	92
# Rejected: 	101
# Iteration: 	29 / 100
# Confirmed: 	360
# Tentative: 	91
# Rejected: 	101
# Iteration: 	30 / 100
# Confirmed: 	360
# Tentative: 	91
# Rejected: 	101
# Iteration: 	31 / 100
# Confirmed: 	360
# Tentative: 	87
# Rejected: 	105
# Iteration: 	32 / 100
# Confirmed: 	360
# Tentative: 	87
# Rejected: 	105
# Iteration: 	33 / 100
# Confirmed: 	360
# Tentative: 	87
# Rejected: 	105
# Iteration: 	34 / 100
# Confirmed: 	360
# Tentative: 	82
# Rejected: 	110
# Iteration: 	35 / 100
# Confirmed: 	360
# Tentative: 	82
# Rejected: 	110
# Iteration: 	36 / 100
# Confirmed: 	360
# Tentative: 	82
# Rejected: 	110
# Iteration: 	37 / 100
# Confirmed: 	360
# Tentative: 	82
# Rejected: 	110
# Iteration: 	38 / 100
# Confirmed: 	360
# Tentative: 	82
# Rejected: 	110
# Iteration: 	39 / 100
# Confirmed: 	360
# Tentative: 	77
# Rejected: 	115
# Iteration: 	40 / 100
# Confirmed: 	360
# Tentative: 	77
# Rejected: 	115
# Iteration: 	41 / 100
# Confirmed: 	360
# Tentative: 	77
# Rejected: 	115
# Iteration: 	42 / 100
# Confirmed: 	360
# Tentative: 	77
# Rejected: 	115
# Iteration: 	43 / 100
# Confirmed: 	361
# Tentative: 	76
# Rejected: 	115
# Iteration: 	44 / 100
# Confirmed: 	361
# Tentative: 	76
# Rejected: 	115
# Iteration: 	45 / 100
# Confirmed: 	361
# Tentative: 	76
# Rejected: 	115
# Iteration: 	46 / 100
# Confirmed: 	361
# Tentative: 	76
# Rejected: 	115
# Iteration: 	47 / 100
# Confirmed: 	361
# Tentative: 	76
# Rejected: 	115
# Iteration: 	48 / 100
# Confirmed: 	361
# Tentative: 	75
# Rejected: 	116
# Iteration: 	49 / 100
# Confirmed: 	364
# Tentative: 	72
# Rejected: 	116
# Iteration: 	50 / 100
# Confirmed: 	364
# Tentative: 	72
# Rejected: 	116
# Iteration: 	51 / 100
# Confirmed: 	365
# Tentative: 	67
# Rejected: 	120
# Iteration: 	52 / 100
# Confirmed: 	365
# Tentative: 	67
# Rejected: 	120
# Iteration: 	53 / 100
# Confirmed: 	365
# Tentative: 	67
# Rejected: 	120
# Iteration: 	54 / 100
# Confirmed: 	365
# Tentative: 	67
# Rejected: 	120
# Iteration: 	55 / 100
# Confirmed: 	365
# Tentative: 	67
# Rejected: 	120
# Iteration: 	56 / 100
# Confirmed: 	365
# Tentative: 	65
# Rejected: 	122
# Iteration: 	57 / 100
# Confirmed: 	365
# Tentative: 	59
# Rejected: 	128
# Iteration: 	58 / 100
# Confirmed: 	365
# Tentative: 	59
# Rejected: 	128
# Iteration: 	59 / 100
# Confirmed: 	365
# Tentative: 	59
# Rejected: 	128
# Iteration: 	60 / 100
# Confirmed: 	365
# Tentative: 	59
# Rejected: 	128
# Iteration: 	61 / 100
# Confirmed: 	365
# Tentative: 	59
# Rejected: 	128
# Iteration: 	62 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	63 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	64 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	65 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	66 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	67 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	68 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	69 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	70 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	71 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	72 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	73 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	74 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	75 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	76 / 100
# Confirmed: 	366
# Tentative: 	58
# Rejected: 	128
# Iteration: 	77 / 100
# Confirmed: 	367
# Tentative: 	57
# Rejected: 	128
# Iteration: 	78 / 100
# Confirmed: 	367
# Tentative: 	54
# Rejected: 	131
# Iteration: 	79 / 100
# Confirmed: 	367
# Tentative: 	54
# Rejected: 	131
# Iteration: 	80 / 100
# Confirmed: 	367
# Tentative: 	54
# Rejected: 	131
# Iteration: 	81 / 100
# Confirmed: 	367
# Tentative: 	54
# Rejected: 	131
# Iteration: 	82 / 100
# Confirmed: 	367
# Tentative: 	52
# Rejected: 	133
# Iteration: 	83 / 100
# Confirmed: 	367
# Tentative: 	52
# Rejected: 	133
# Iteration: 	84 / 100
# Confirmed: 	367
# Tentative: 	52
# Rejected: 	133
# Iteration: 	85 / 100
# Confirmed: 	368
# Tentative: 	51
# Rejected: 	133
# Iteration: 	86 / 100
# Confirmed: 	368
# Tentative: 	51
# Rejected: 	133
# Iteration: 	87 / 100
# Confirmed: 	368
# Tentative: 	48
# Rejected: 	136
# Iteration: 	88 / 100
# Confirmed: 	368
# Tentative: 	48
# Rejected: 	136
# Iteration: 	89 / 100
# Confirmed: 	368
# Tentative: 	48
# Rejected: 	136
# Iteration: 	90 / 100
# Confirmed: 	368
# Tentative: 	48
# Rejected: 	136
# Iteration: 	91 / 100
# Confirmed: 	368
# Tentative: 	48
# Rejected: 	136
# Iteration: 	92 / 100
# Confirmed: 	368
# Tentative: 	47
# Rejected: 	137
# Iteration: 	93 / 100
# Confirmed: 	368
# Tentative: 	43
# Rejected: 	141
# Iteration: 	94 / 100
# Confirmed: 	368
# Tentative: 	43
# Rejected: 	141
# Iteration: 	95 / 100
# Confirmed: 	368
# Tentative: 	43
# Rejected: 	141
# Iteration: 	96 / 100
# Confirmed: 	368
# Tentative: 	43
# Rejected: 	141
# Iteration: 	97 / 100
# Confirmed: 	368
# Tentative: 	43
# Rejected: 	141
# Iteration: 	98 / 100
# Confirmed: 	369
# Tentative: 	42
# Rejected: 	141
# Iteration: 	99 / 100
# Confirmed: 	369
# Tentative: 	42
# Rejected: 	141
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	369
# Tentative: 	13
# Rejected: 	141
# BorutaPy(alpha=0.05,
#      estimator=RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=6, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=477, n_jobs=-1, oob_score=False,
#             random_state=<mtrand.RandomState object at 0x7f0f9c072c80>,
#             verbose=0, warm_start=False),
#      max_iter=100, n_estimators='auto', perc=100,
#      random_state=<mtrand.RandomState object at 0x7f0f9c072c80>,
#      two_step=True, verbose=2)

# %%
print ('Number of selected features:')
print (boruta_selector.n_features_)
# Out:
# Number of selected features:
# 369

# %%
feature_df = pd.DataFrame(train.columns.tolist(), columns=['features'])

# %%
feature_df['rank']=boruta_selector.ranking_

# %%
feature_df = feature_df.sort_values('rank', ascending=True).reset_index(drop=True)

# %%
feature_df
# Out:
#                                           features  rank
# 0         last_pay_money_now_browse_product3_ratio     1
# 1                      order_vs_actiontype_1_ratio     1
# 2                     operate_num_after_last_order     1
# 3                        open_num_after_last_order     1
# 4                               open_app_std_delta     1
# 5                                   open_app_ratio     1
# 6                         open_app_pay_money_ratio     1
# 7                              open_app_mean_delta     1
# 8                               open_app_max_delta     1
# 9                       multi_order_has_good_order     1
# 10                    most_free_month_action_count     1
# 11                     order_vs_actiontype_4_ratio     1
# 12                                 most_free_month     1
# 13                                  month_11_count     1
# 14                                  month_10_count     1
# 15                     last_time_x_actiontypr_mean     1
# 16                            last_time_order_year     1
# 17                      last_time_order_weekofyear     1
# 18                         last_time_order_weekday     1
# 19          last_time_order_now_action_total_count     1
# 20       last_time_order_now_action_open_app_count     1
# 21   last_time_order_now_action_fillin_form7_count     1
# 22   last_time_order_now_action_fillin_form6_count     1
# 23                              month_action_count     1
# 24                     order_vs_actiontype_5_ratio     1
# 25                     order_vs_actiontype_6_ratio     1
# 26                                 pay_money_ratio     1
# 27                             timespanmean_last_3     1
# 28                              timespanmax_last_9     1
# 29                              timespanmax_last_8     1
# ..                                             ...   ...
# 522              last2_action_pay_money_time_delta   143
# 523                              histord_sum_cont2   144
# 524                       three_gram_789_time_mean   145
# 525                         fillin_form7_min_delta   146
# 526                         submit_order_min_delta   147
# 527                            pay_money_min_delta   148
# 528                       three_gram_123_time_mean   149
# 529                         actiontypeproplast20_8   150
# 530                 pre_90days_order_country_count   150
# 531                    three_gram_action_123_ratio   152
# 532                           pay_money_mean_delta   153
# 533                                 action1o2_rate   154
# 534               pre_90days_order_continent_count   155
# 535                        actiontimespancount_7_8   156
# 536                                action2345_rate   157
# 537                              histord_sum_cont4   158
# 538                            pay_money_max_delta   159
# 539                         2016_order_month_count   160
# 540                                       age_lg90   161
# 541                                     gender_man   162
# 542                                       age_lg70   164
# 543                                       age_lg60   164
# 544                                       age_lg80   164
# 545                                       age_lg00   166
# 546                            both_year_has_order   166
# 547                        actiontimespancount_8_9   169
# 548                              histord_sum_cont5   169
# 549                                       age_None   169
# 550                                user_rating_std   171
# 551                      last_openapp_browse_count   171
#
# [552 rows x 2 columns]

# %%
print ('Top %d features:' % boruta_selector.n_features_)
print (feature_df.head(boruta_selector.n_features_))
# Out:
# Top 369 features:
#                                           features  rank
# 0         last_pay_money_now_browse_product3_ratio     1
# 1                      order_vs_actiontype_1_ratio     1
# 2                     operate_num_after_last_order     1
# 3                        open_num_after_last_order     1
# 4                               open_app_std_delta     1
# 5                                   open_app_ratio     1
# 6                         open_app_pay_money_ratio     1
# 7                              open_app_mean_delta     1
# 8                               open_app_max_delta     1
# 9                       multi_order_has_good_order     1
# 10                    most_free_month_action_count     1
# 11                     order_vs_actiontype_4_ratio     1
# 12                                 most_free_month     1
# 13                                  month_11_count     1
# 14                                  month_10_count     1
# 15                     last_time_x_actiontypr_mean     1
# 16                            last_time_order_year     1
# 17                      last_time_order_weekofyear     1
# 18                         last_time_order_weekday     1
# 19          last_time_order_now_action_total_count     1
# 20       last_time_order_now_action_open_app_count     1
# 21   last_time_order_now_action_fillin_form7_count     1
# 22   last_time_order_now_action_fillin_form6_count     1
# 23                              month_action_count     1
# 24                     order_vs_actiontype_5_ratio     1
# 25                     order_vs_actiontype_6_ratio     1
# 26                                 pay_money_ratio     1
# 27                             timespanmean_last_3     1
# 28                              timespanmax_last_9     1
# 29                              timespanmax_last_8     1
# ..                                             ...   ...
# 339                                  action_last_1     1
# 340               avg_operate_num_after_last_order     1
# 341                                  action_last_2     1
# 342                  action_5_num_after_last_order     1
# 343                                  action_last_3     1
# 344                                  action_last_4     1
# 345                  action_type_15_time_delta_max     1
# 346                 action_type_15_time_delta_mean     1
# 347                  action_type_15_time_delta_min     1
# 348                  action_type_15_time_delta_std     1
# 349                  action_type_16_time_delta_max     1
# 350                 action_type_16_time_delta_mean     1
# 351                avg_browse_num_after_last_order     1
# 352                           browse_product_ratio     1
# 353                      actiontime_seq_fft_real_2     1
# 354                     browse_product3_mean_delta     1
# 355                       browse_product_min_delta     1
# 356                  action_4_num_after_last_order     1
# 357                      browse_product_mean_delta     1
# 358                browse_product2_pay_money_ratio     1
# 359                  action_1_num_after_last_order     1
# 360                         action59seqentialratio     1
# 361                                  8_9_diff_time     1
# 362                      browse_product3_max_delta     1
# 363                       browse_product_max_delta     1
# 364                                  7_8_diff_time     1
# 365                      browse_product3_min_delta     1
# 366                browse_product3_pay_money_ratio     1
# 367                          browse_product3_ratio     1
# 368                      browse_product3_std_delta     1
#
# [369 rows x 2 columns]

# %%
sum(boruta_selector.support_)
# Out:
# 369

# %%
# check ranking of features
print ('\n Feature ranking:')
print (boruta_selector.ranking_.shape)
# Out:
#  Feature ranking:
# (552,)

# %%
print feature_df[feature_df['rank'] > 2]['features'].values.tolist()
# Out:
# ['raing3_ratio', 'action_last_5', 'days_ratio_since_last_order', 'last_submit_order_action_count', 'nearestDiff_max9', 'order_vs_actiontype_8_ratio', u'userid', 'action_type_68_time_delta_std', 'raing1_ratio', '234_5_diff_time', 'nearestDiff_min9', 'avg_rating', 'action56_rate', 'two_gram_89_time_max', 'has_comment_flag', 'three_gram_action_456_ratio', 'action_2_num_after_last_order', 'action_last_18', 'last_time_order_now_action_submit_order_count', 'last_time_order_now_action_browse_product2_count', 'two_gram_89_last_time', 'raing2_ratio', 'nearestTime3', 'raing4_ratio', 'submit_order_pay_money_ratio', 'action_last_19', 'action_last_20', 'month_4_count', '234_9_diff_time', 'actiontype_seq_kalman_real_1', 'avg_rating_type0', 'two_gram_12_time_min', 'timespan_last_8', 'actiontypeproplast20_2', 'open_app_min_delta', 'last_time_order_now_has_submited_order', 'action_last_17', 'month_6_count', 'two_gram_12_time_max', 'actiontypeproplast20_mean', 'two_gram_12_last_time', 'action_last_15', 'actiontypeprop_3', 'browse_product2_ratio', 'timespan_last_9', 'order_vs_actiontype_2_ratio', 'three_gram_456_time_min', 'three_gram_456_time_mean', 'action_last_16', 'timespan_last_7', 'has_pay_money', 'last_pay_money_action_count', 'three_gram_456_time_max', 'actiontypeproplast20_7', 'nearestInterval_min9', 'two_gram_12_time_std', 'two_gram_12_time_mean', 'nearestDistance9', 'avg_days_between_order', 'action_last_11', 'last_time_order_now_has_paied_money', 'browse_product2_max_delta', 'month_5_count', 'browse_product2_std_delta', 'action_last_7', 'action_8_num_after_last_order', 'action_last_6', 'action_last_10', 'order_vs_actiontype_9_ratio', 'action_last_14', 'actiontimespanlast_7_8', 'action_last_13', 'last_time_order_now_action_pay_money_count', 'action_last_8', 'action_last_9', 'action_7_num_after_last_order', 'browse_product2_mean_delta', 'order_vs_actiontype_3_ratio', 'commentsKeyWords_score', 'actiontypeproplast20_3', 'commentsKeyWords_score_last_order', 'year_action_count', 'nearestActiontime3', 'tags_score', 'action_9_num_after_last_order', 'action_last_12', 'timespan_lastord_2_3', 'two_gram_action_23_ratio', 'two_gram_23_time_std', 'finalAction_8', 'month_7_count', 'two_gram_23_time_min', 'nearestDiff_min3', 'month_12_count', 'last_action_browse_product2_time_delta', 'action_type_810_time_delta_min', 'rating_last_order', 'two_gram_23_time_mean', 'month_3_count', 'month_8_count', 'fillin_form7_max_delta', 'nearestDistance3', 'action5_rate', 'month_9_count', 'tags_score_last_order', 'action_type_210_time_delta_min', 'month_2_count', 'three_gram_789_time_min', 'last2_action_browse_product2_time_delta', 'action_type_710_time_delta_mean', 'month_1_count', 'action_type_810_time_delta_max', 'three_gram_789_last_time', 'last2_action_submit_order_time_delta', 'last_browse_product2_action_count', 'gender_None', 'province_code', 'actiontypeproplast20_9', 'fillin_form7_std_delta', 'gender_woman', 'two_gram_action_34_ratio', 'two_gram_34_time_min', 'count_234_9_rate', 'histord_sum_cont3', 'action_3_num_after_last_order', 'submit_order_mean_delta', 'action_type_910_time_delta_min', 'three_gram_789_time_max', 'last2_action_fillin_form7_time_delta', 'two_gram_34_time_max', 'fillin_form7_mean_delta', 'pre_90days_order_city_count', 'three_gram_action_789_ratio', '2016_order_count', 'browse_product2_min_delta', 'pay_money_std_delta', 'submit_order_max_delta', 'submit_order_std_delta', 'action_type_710_time_delta_min', 'pre_90days_order_count', 'last2_action_pay_money_time_delta', 'histord_sum_cont2', 'three_gram_789_time_mean', 'fillin_form7_min_delta', 'submit_order_min_delta', 'pay_money_min_delta', 'three_gram_123_time_mean', 'actiontypeproplast20_8', 'pre_90days_order_country_count', 'three_gram_action_123_ratio', 'pay_money_mean_delta', 'action1o2_rate', 'pre_90days_order_continent_count', 'actiontimespancount_7_8', 'action2345_rate', 'histord_sum_cont4', 'pay_money_max_delta', '2016_order_month_count', u'age_lg90', 'gender_man', u'age_lg70', u'a ...
